# %% [markdown]
# <a href="https://cognitiveclass.ai/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0101ENSkillsNetwork20718188-2021-01-01"><img src = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width = 400> </a>
#
# <h1 align=center><font size = 5>Classification Models with Keras</font></h1>

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, we will learn how to use the Keras library to build models for classificaiton problems. We will use the popular MNIST dataset, a dataset of images, for a change.
#
# The <strong>MNIST database</strong>, short for Modified National Institute of Standards and Technology database, is a large database of handwritten digits that is commonly used for training various image processing systems. The database is also widely used for training and testing in the field of machine learning.
#
# The MNIST database contains 60,000 training images and 10,000 testing images of digits written by high school students and employees of the United States Census Bureau.
#
# Also, this way, will get to compare how conventional neural networks compare to convolutional neural networks, that we will build in the next module.

# %% [markdown]
# <h2>Classification Models with Keras</h2>
#
# <h3>Objective for this Notebook<h3>
# <h5> 1. Use of MNIST database for training various image processing systems</h5>
# <h5> 2. Build a Neural Network </h5>
# <h5> 3. Train and Test the Network. </h5>
#
# <p>This link will be used by your peers to assess your project. In your web app, your peers will be able to upload an image, which will then be classified using your custom classifier you connected to the web app. Your project will be graded by how accurately your app can classify <b>Fire</b>, <b>Smoke</b> and <b>Neutral (No Fire or Smoke)</b>.<p>

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1.  <a href="https://#item312">Import Keras and Packages</a>
# 2.  <a href="https://#item322">Build a Neural Network</a>
# 3.  <a href="https://#item332">Train and Test the Network</a>
#
# </font>
# </div>

# %% [markdown]
# <a id='item312'></a>

# %% [markdown]
# ## Import Keras and Packages

# %% [markdown]
# Let's start by importing Keras and some of its modules.

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented. 
# If you run this notebook on a different environment, e.g. your desktop, you may need to uncomment and install certain libraries.

# !pip install tensorflow==2.8.0
# !pip install numpy==1.21.4
# !pip install pandas==1.3.4
# !pip install keras==2.1.6
# !pip install matplotlib==3.5.0
# Out:
# Collecting tensorflow==2.8.0
#   Downloading tensorflow-2.8.0-cp39-cp39-macosx_10_14_x86_64.whl (217.5 MB)
#      |████████████████████████████████| 217.5 MB 646 kB/s eta 0:00:01
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting typing-extensions>=3.6.6
#   Downloading typing_extensions-4.1.1-py3-none-any.whl (26 kB)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 1.3 MB/s eta 0:00:01
# Collecting absl-py>=0.4.0
#   Using cached absl_py-1.0.0-py3-none-any.whl (126 kB)
# Requirement already satisfied: six>=1.12.0 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from tensorflow==2.8.0) (1.16.0)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.44.0-cp39-cp39-macosx_10_10_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 2.5 MB/s eta 0:00:01
# Collecting flatbuffers>=1.12
#   Downloading flatbuffers-2.0-py2.py3-none-any.whl (26 kB)
# Collecting keras<2.9,>=2.8.0rc0
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 3.5 MB/s eta 0:00:01
# Collecting libclang>=9.0.1
#   Downloading libclang-13.0.0-py2.py3-none-macosx_10_9_x86_64.whl (13.0 MB)
#      |████████████████████████████████| 13.0 MB 1.2 MB/s eta 0:00:01
# Collecting termcolor>=1.1.0
#   Using cached termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.20.0-cp39-cp39-macosx_10_9_x86_64.whl (962 kB)
#      |████████████████████████████████| 962 kB 3.6 MB/s eta 0:00:01
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.24.0-cp39-cp39-macosx_10_14_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 3.8 MB/s eta 0:00:01
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.14.0-cp39-cp39-macosx_10_9_x86_64.whl (35 kB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: numpy>=1.20 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from tensorflow==2.8.0) (1.21.4)
# Collecting tensorboard<2.9,>=2.8
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 4.1 MB/s eta 0:00:01
# Requirement already satisfied: setuptools in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from tensorflow==2.8.0) (58.0.4)
# Collecting keras-preprocessing>=1.1.1
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: h5py>=2.9.0 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from tensorflow==2.8.0) (3.6.0)
# Collecting gast>=0.2.1
#   Using cached gast-0.5.3-py3-none-any.whl (19 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow==2.8.0) (0.37.1)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-macosx_10_9_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 3.6 MB/s eta 0:00:01
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.6.2-py2.py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 631 kB/s eta 0:00:01
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.3.6-py3-none-any.whl (97 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.27.1)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting werkzeug>=0.11.15
#   Using cached Werkzeug-2.1.1-py3-none-any.whl (224 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.8-py3-none-any.whl (39 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.0.0-py3-none-any.whl (9.1 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4
#   Using cached importlib_metadata-4.11.3-py3-none-any.whl (18 kB)
# Collecting zipp>=0.5
#   Using cached zipp-3.8.0-py3-none-any.whl (5.4 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2021.10.8)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Building wheels for collected packages: termcolor
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4848 sha256=f644d402f87e3d685fcbb76645299e05e87af20010f9e48b60c0179fd8aae8d7
#   Stored in directory: /Users/krzysztofkolmus/Library/Caches/pip/wheels/b6/0d/90/0d1bbd99855f99cb2f6c2e5ff96f8023fad8ec367695f7d72d
# Successfully built termcolor
# Installing collected packages: pyasn1, zipp, rsa, pyasn1-modules, oauthlib, cachetools, requests-oauthlib, importlib-metadata, google-auth, werkzeug, tensorboard-plugin-wit, tensorboard-data-server, protobuf, markdown, grpcio, google-auth-oauthlib, absl-py, wrapt, typing-extensions, tf-estimator-nightly, termcolor, tensorflow-io-gcs-filesystem, tensorboard, opt-einsum, libclang, keras-preprocessing, keras, google-pasta, gast, flatbuffers, astunparse, tensorflow
#   Attempting uninstall: keras
#     Found existing installation: Keras 2.1.6
#     Uninstalling Keras-2.1.6:
#       Successfully uninstalled Keras-2.1.6
# Successfully installed absl-py-1.0.0 astunparse-1.6.3 cachetools-5.0.0 flatbuffers-2.0 gast-0.5.3 google-auth-2.6.2 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.44.0 importlib-metadata-4.11.3 keras-2.8.0 keras-preprocessing-1.1.2 libclang-13.0.0 markdown-3.3.6 oauthlib-3.2.0 opt-einsum-3.3.0 protobuf-3.20.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.1 rsa-4.8 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.8.0 tensorflow-io-gcs-filesystem-0.24.0 termcolor-1.1.0 tf-estimator-nightly-2.8.0.dev2021122109 typing-extensions-4.1.1 werkzeug-2.1.1 wrapt-1.14.0 zipp-3.8.0
# Requirement already satisfied: numpy==1.21.4 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (1.21.4)
# Requirement already satisfied: pandas==1.3.4 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from pandas==1.3.4) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from pandas==1.3.4) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from pandas==1.3.4) (1.21.4)
# Requirement already satisfied: six>=1.5 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas==1.3.4) (1.16.0)
# Collecting keras==2.1.6
#   Using cached Keras-2.1.6-py2.py3-none-any.whl (339 kB)
# Requirement already satisfied: h5py in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from keras==2.1.6) (3.6.0)
# Requirement already satisfied: six>=1.9.0 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from keras==2.1.6) (1.16.0)
# Requirement already satisfied: pyyaml in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from keras==2.1.6) (6.0)
# Requirement already satisfied: numpy>=1.9.1 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from keras==2.1.6) (1.21.4)
# Requirement already satisfied: scipy>=0.14 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from keras==2.1.6) (1.8.0)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.8.0
#     Uninstalling keras-2.8.0:
#       Successfully uninstalled keras-2.8.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires keras<2.9,>=2.8.0rc0, but you have keras 2.1.6 which is incompatible.
# Successfully installed keras-2.1.6
# Requirement already satisfied: matplotlib==3.5.0 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (3.5.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from matplotlib==3.5.0) (4.31.2)
# Requirement already satisfied: setuptools-scm>=4 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from matplotlib==3.5.0) (6.4.2)
# Requirement already satisfied: numpy>=1.17 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from matplotlib==3.5.0) (1.21.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from matplotlib==3.5.0) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from matplotlib==3.5.0) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from matplotlib==3.5.0) (9.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from matplotlib==3.5.0) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from matplotlib==3.5.0) (21.3)
# Requirement already satisfied: cycler>=0.10 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from matplotlib==3.5.0) (0.11.0)
# Requirement already satisfied: six>=1.5 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib==3.5.0) (1.16.0)
# Requirement already satisfied: tomli>=1.0.0 in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from setuptools-scm>=4->matplotlib==3.5.0) (2.0.1)
# Requirement already satisfied: setuptools in /Users/krzysztofkolmus/Library/r-miniconda/lib/python3.9/site-packages (from setuptools-scm>=4->matplotlib==3.5.0) (58.0.4)

# %%
import keras

from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical

# %% [markdown]
# Since we are dealing we images, let's also import the Matplotlib scripting layer in order to view the images.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# The Keras library conveniently includes the MNIST dataset as part of its API. You can check other datasets within the Keras library [here](https://keras.io/datasets/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0101ENSkillsNetwork20718188-2021-01-01).
#
# So, let's load the MNIST dataset from the Keras library. The dataset is readily divided into a training set and a test set.

# %%
# import the data
from keras.datasets import mnist

# read the data
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %% [markdown]
# Let's confirm the number of images in each set. According to the dataset's documentation, we should have 60000 images in X_train and 10000 images in the X_test.

# %%
X_train.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/krzysztofkolmus/Desktop/Courses/IBM_Introduction_to_Deep_Learning_and_Neural_Networks_with_Keras/Labs/DL0101EN-3-2-Classification-with-Keras-py-v1.0__1_.ipynb Cell 9' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/krzysztofkolmus/Desktop/Courses/IBM_Introduction_to_Deep_Learning_and_Neural_Networks_with_Keras/Labs/DL0101EN-3-2-Classification-with-Keras-py-v1.0__1_.ipynb#ch0000008?line=0'>1</a> X_train
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# The first number in the output tuple is the number of images, and the other two numbers are the size of the images in datset. So, each image is 28 pixels by 28 pixels.

# %% [markdown]
# Let's visualize the first image in the training set using Matplotlib's scripting layer.

# %%
plt.imshow(X_train[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/krzysztofkolmus/Desktop/Courses/IBM_Introduction_to_Deep_Learning_and_Neural_Networks_with_Keras/Labs/DL0101EN-3-2-Classification-with-Keras-py-v1.0__1_.ipynb Cell 9' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/krzysztofkolmus/Desktop/Courses/IBM_Introduction_to_Deep_Learning_and_Neural_Networks_with_Keras/Labs/DL0101EN-3-2-Classification-with-Keras-py-v1.0__1_.ipynb#ch0000008?line=0'>1</a> plt.imshow(X_train[0])
#
# NameError: name 'plt' is not defined

# %% [markdown]
# With conventional neural networks, we cannot feed in the image as input as is. So we need to flatten the images into one-dimensional vectors, each of size 1 x (28 x 28) = 1 x 784.

# %%
# flatten images into one-dimensional vector

num_pixels = X_train.shape[1] * X_train.shape[2] # find size of one-dimensional vector

X_train = X_train.reshape(X_train.shape[0], num_pixels).astype('float32') # flatten training images
X_test = X_test.reshape(X_test.shape[0], num_pixels).astype('float32') # flatten test images

# %% [markdown]
# Since pixel values can range from 0 to 255, let's normalize the vectors to be between 0 and 1.

# %%
# normalize inputs from 0-255 to 0-1
X_train = X_train / 255
X_test = X_test / 255
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/krzysztofkolmus/Desktop/Courses/IBM_Introduction_to_Deep_Learning_and_Neural_Networks_with_Keras/Labs/DL0101EN-3-2-Classification-with-Keras-py-v1.0__1_.ipynb Cell 10' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/krzysztofkolmus/Desktop/Courses/IBM_Introduction_to_Deep_Learning_and_Neural_Networks_with_Keras/Labs/DL0101EN-3-2-Classification-with-Keras-py-v1.0__1_.ipynb#ch0000009?line=0'>1</a> # normalize inputs from 0-255 to 0-1
# ----> <a href='vscode-notebook-cell:/Users/krzysztofkolmus/Desktop/Courses/IBM_Introduction_to_Deep_Learning_and_Neural_Networks_with_Keras/Labs/DL0101EN-3-2-Classification-with-Keras-py-v1.0__1_.ipynb#ch0000009?line=1'>2</a> X_train = X_train / 255
#       <a href='vscode-notebook-cell:/Users/krzysztofkolmus/Desktop/Courses/IBM_Introduction_to_Deep_Learning_and_Neural_Networks_with_Keras/Labs/DL0101EN-3-2-Classification-with-Keras-py-v1.0__1_.ipynb#ch0000009?line=2'>3</a> X_test = X_test / 255
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# Finally, before we start building our model, remember that for classification we need to divide our target variable into categories. We use the to_categorical function from the Keras Utilities package.

# %%
# one hot encode outputs
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

num_classes = y_test.shape[1]
print(num_classes)

# %% [markdown]
# <a id='item322'></a>

# %% [markdown]
# ## Build a Neural Network

# %%
# define classification model
def classification_model():
    # create model
    model = Sequential()
    model.add(Dense(num_pixels, activation='relu', input_shape=(num_pixels,)))
    model.add(Dense(100, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    
    
    # compile model
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %% [markdown]
# <a id='item332'></a>

# %% [markdown]
# ## Train and Test the Network

# %%
# build the model
model = classification_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)

# %% [markdown]
# Let's print the accuracy and the corresponding error.

# %%
print('Accuracy: {}% \n Error: {}'.format(scores[1], 1 - scores[1]))

# %% [markdown]
# Just running 10 epochs could actually take over 20 minutes. But enjoy the results as they are getting generated.

# %% [markdown]
# Sometimes, you cannot afford to retrain your model everytime you want to use it, especially if you are limited on computational resources and training your model can take a long time. Therefore, with the Keras library, you can save your model after training. To do that, we use the save method.

# %%
model.save('classification_model.h5')

# %% [markdown]
# Since our model contains multidimensional arrays of data, then models are usually saved as .h5 files.

# %% [markdown]
# When you are ready to use your model again, you use the load_model function from <strong>keras.models</strong>.

# %%
from keras.models import load_model

# %%
pretrained_model = load_model('classification_model.h5')

# %% [markdown]
# ### Thank you for completing this lab!
#
# This notebook was created by [Alex Aklson](https://www.linkedin.com/in/aklson/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0101ENSkillsNetwork20718188-2021-01-01). I hope you found this lab interesting and educational. Feel free to contact me if you have any questions!

# %% [markdown]
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description                                          |
# | ----------------- | ------- | ---------- | ----------------------------------------------------------- |
# | 2020-09-21        | 2.0     | Srishti    | Migrated Lab to Markdown and added to course repo in GitLab |
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>

# %% [markdown]
# This notebook is part of a course on **Coursera** called *Introduction to Deep Learning & Neural Networks with Keras*. If you accessed this notebook outside the course, you can take this course online by clicking [here](https://cocl.us/DL0101EN_Coursera_Week3\_LAB2).

# %% [markdown]
# <hr>
#
# Copyright © 2019 [IBM Developer Skills Network](https://cognitiveclass.ai/?utm_medium=dswb&utm_source=bducopyrightlink&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0101ENSkillsNetwork20718188-2021-01-01&utm_campaign=bdu). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0101ENSkillsNetwork20718188-2021-01-01).
